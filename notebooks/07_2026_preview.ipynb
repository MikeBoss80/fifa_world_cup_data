# %% [markdown]
# # Análisis 7: Preview Mundial 2026
# ## Análisis de grupos, equipos y fixture
#
# **Preguntas a responder:**
# 1. ¿Qué grupo es el "grupo de la muerte"?
# 2. ¿Cómo les fue a otros debutantes históricamente?
# 3. ¿Qué confederación tiene más representación?
# 4. ¿El formato de 48 equipos cambia la dinámica?

# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('..')
import matplotlib.pyplot as plt
import seaborn as sns
from src.visualization import set_style, save_figure

set_style()

teams = pd.read_csv('../data/processed/teams_2026_clean.csv')
fixtures = pd.read_csv('../data/processed/fixtures_2026_clean.csv')
editions = pd.read_csv('../data/processed/editions_clean.csv')
print('Data loaded successfully')
# Out:
# Data loaded successfully

# %% [markdown]
# ## Análisis 1: Distribución de equipos por confederación

# %%
conf_counts = teams['confederation'].value_counts()
display(conf_counts)
# Out:
# confederation
# UEFA        16
# CAF         10
# AFC          9
# CONCACAF     6
# CONMEBOL     6
# OFC          1
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(x=conf_counts.values, y=conf_counts.index, palette='viridis', ax=ax)
ax.set_title('Teams per Confederation - World Cup 2026')
ax.set_xlabel('Number of Teams')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\migue\AppData\Local\Temp\ipykernel_25328\3710346958.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=conf_counts.values, y=conf_counts.index, palette='viridis', ax=ax)

# %% [markdown]
# ## Análisis 2: Ranking promedio por grupo

# %%
group_rank = teams.groupby('group')['fifa_rank'].mean().sort_values()
display(group_rank)
# Out:
# group
# F    26.00
# I    30.00
# J    32.50
# K    32.75
# L    33.25
# B    34.00
# A    35.25
# C    36.00
# H    36.50
# D    37.00
# E    37.00
# G    38.50
# Name: fifa_rank, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.barplot(x=group_rank.index, y=group_rank.values, palette='viridis', ax=ax)
ax.set_title('Average FIFA Rank by Group - World Cup 2026')
ax.set_xlabel('Group')
ax.set_ylabel('Average FIFA Rank')
ax.axhline(y=group_rank.mean(), color='red', linestyle='--', label=f'Overall avg: {group_rank.mean():.1f}')
ax.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\migue\AppData\Local\Temp\ipykernel_25328\3483365695.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=group_rank.index, y=group_rank.values, palette='viridis', ax=ax)

# %% [markdown]
# ## Análisis 2: Debutantes en 2026

# %%
debutants = teams[teams['is_debutant'] == True]
display(debutants[['team', 'group', 'confederation', 'fifa_rank', 'coach']])
# Out:
#           team group confederation  fifa_rank            coach
# 17     Curaçao     E      CONCACAF         81    Dick Advocaat
# 29  Cape Verde     H           CAF         70      Pedro Brito
# 39      Jordan     J           AFC         68  Hussain Ammouta
# 42  Uzbekistan     K           AFC         62   Srecko Katanec

# %% [markdown]
# ## Conclusiones
#
# **Escribe aquí tus hallazgos.**
#
# - ¿Qué grupo es el grupo de la muerte?
# - ¿Cómo les fue a otros debutantes históricamente?
# - ¿Qué predicciones puedes hacer para 2026?
